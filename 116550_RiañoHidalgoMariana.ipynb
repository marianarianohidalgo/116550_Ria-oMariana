# %%
"""
Sin utilizar el comando abs, escribir un programa que calcule e imprima 
el valor absoluto de cualquier número (sea entero o decimal)
"""


x=float(input('Ingrese un numero:'))

if x<0:
    x=x*-1    #Al multiplicar por -1 se convierte en positivo
    print('El valor absoluto es: ' ,x)

# %%
"""
Leer un número entero y escribirlo en reversa. 
Por ejemplo, 461975 será 579164. No utilizar comandos de ordenamiento.'
"""

x=int(input('Digite un numero entero:'))

Reversa=()

while x > 0:
    Reversa+=(x % 10) #Sacamos el residuo del número
    x=x//10           #El número se divide para sacar la siguiente cifra
    
print(Reversa)

# %%
"""
Leer un número entero de 3 dígitos y determinar si contiene el dígito 8.
"""

x = int(input('Numero entero de 3 digitos:'))

e=[]


if x in range(100,1000,1): 
    while x>0:                 
        e.append(x%10)  #Agrega los digitos ingresados a la lista
        x=x//10         #El número se divide para sacar la siguiente cifra

    for i in range(len(e)):
           
        if e[i] == 8:          #Si en cada posicion hay 8 
            print('Contiene el digito 8')
        else:
            print('No contiene el digito 8')
        break
        
        
        
        
            
            
elif x not in range(100,999,1):
    print('No es numero de 3 digitos')

# %%
"""
Lea un número entero positivo y determine la suma de sus dígitos pares.
"""
def suma_numeros_pares(x):
    sum=0
    while x>0:
        residuo=int(x%10)    #Volvemos el residuo del número a un entero.
        x=x/10               #El número se divide para sacar la cifra par.
        if(residuo%2==0):    #Un número dividido entre 2 da como resultado
                             #la cifra par. 
            sum=sum+residuo  #Se suman las cifras pares que han salido.
    return sum
        
while True:
    try:
        num=int(input("Escriba un número entero positivo = "))
        if num>=0:
            break
        else:
            print("El número ingresado no es positivo. Inténte de nuevo")
    except ValueError:
        print("El caracter ingresado no es correcto. Inténtelo de nuevo")
sum=suma_numeros_pares(num)
if sum>=0:
    print("La suma de los números pares es", sum)

# %%
"""
Leer un número entero y determine el número de cincos que están consecutivos
en un número. Por ejemplo, en 5512355551 hay 6 cincos consecutivos.
"""

def contador_de_cincos(x):
    con=0
    while x>0:
        dig1=x%10   #Sacamos el residuo del número 
        x=x//10     #El número se divide para sacar la siguiente cifra
        dig2=x%10   #Lo mismo para el segundo digito
        if dig1==5 and dig2==5:       
            con+=2              #Si el dig1 y dig2 son iguales a 5 entonces el 
            num1=x//10          #contador dice que hay dos 5 consecutivos
            dig3=num1%10        
            if dig2==5 and dig3==5:   #igual para el dig2 y dig3
                con+=1               
                if dig1==5 and dig3==5:   
                    con-=2
    return con
while True:
    try:
        num=int(input(f"Escriba un número entero que contenga cincos = "))
        if num<0:
            num*=(-1)
        break
    except ValueError:
        print("El caracter ingresado es incorrecto. Inténtelo de nuevo.")

con=contador_de_cincos(num)
if con>0:
    print("El número de cincos consecutivos que contiene el número\
 ingresado es",con,".")
else:
    print("El número ingresado NO contiene cincos consecutivos.")

# %%
"""
Leer un número entero y 
determinar si la suma de sus dígitos es un número de Fibonacci.
"""

def suma_digitos(x): 
    cont=0
    while x>0:
        residuo=x%10             
        x=x//10                  
        if residuo>0:             
            cont=cont+residuo
    return cont

def numero_fibonacci(x):
    num1=0
    num2=1
    resultado=False
    while(num1<=x):
        if (num1==x):
            resultado=True
        suma=num1+num2
        num1=num2
        num2=suma
    return resultado

while True:
    try:
        num=int(input("Escriba un número entero = "))
        break
    except ValueError:
        print("El caracter ingresado es incorrecto.")

cont=suma_digitos(num)
if cont<0:
    cont=cont*(-1)

resultado=numero_fibonacci(cont)
if  resultado:
    print("La suma de los dígitos en valor absoluto del número ingresado \
es",cont,".\nY el número",cont,"es de la serie fibonacci.")
else:
    print("La suma de los dígitos en valor absoluto es el número",cont,"\n\
Y no es de la serie fibonacci.")

# %%
"""
Lea un número entero positivo y determine si existen en el número dígitos 
repetidos. Reporte cuales son los dígitos repetidos
"""

def digitos_repetidos(x):
    con0 = 0; con1 = 0; con2 = 0; con3 = 0; con4 = 0; con5 = 0; con6 = 0
    con7 = 0; con8 = 0; con9 = 0 
    while x > 0:
        res = x%10
        x = x//10
        if res==0: con0=con0+1
        elif res==1: con1=con1+1
        elif res==2: con2=con2+1
        elif res==3: con3=con3+1
        elif res==4: con4=con4+1
        elif res==5: con5=con5+1
        elif res==6: con6=con6+1
        elif res==7: con7=con7+1
        elif res==8: con8=con8+1
        elif res==9: con9=con9+1
    return con0,con1,con2,con3,con4,con5,con6,con7,con8,con9

while True:
    try:
        num=int(input("Escriba un número entero positivo = "))
        if num>0:
            break
        else:
            print("El número ingresado es incorrecto. Inténtelo de nuevo.")
    except ValueError:
        print("El caracter ingresado es incorrecto.")
    
con0,con1,con2,con3,con4,con5,con6,con7,con8,con9=digitos_repetidos(num)
if num>0: print("El número se repite en el número ingresado:\n0:",con0,"\
veces\n1:",con1,"veces\n2:",con2,"veces\n3:",con3,"veces\n4:",con4,"veces\
\n5:",con5,"veces\n6:",con6,"veces\n7:",con7,"veces\n8:",con8,"veces\
\n9:",con9,"veces")

# %%
"""
Iterar a través de los primeros cien enteros positivos, 
buscando los múltiplos de 3 e imprimiendo y almacenándolos en
una lista hasta encontrar los primeros 15 de ellos. 
Una vez encontrados, continuar iterando en busca de los múltiplos
de 4 y almacenarlos en otra lista.
"""

lista3=[]  #Multiplos de 3
lista4=[] #Multiplos de 4

for i in range(0,101):
    x=i//3  
    if x*3==i: 
        lista3.append(i)
    lista1=lista3[0:15]             #primeros 15 múltiplos de 3
print('Los primeros 15 multiplos de 3 son:', lista1)

for c in range(42,101):
    y=c//4
    if y*4==c:
        lista4.append(c)
    lista4[42:101]

print('Los multiplos de 4, despues del 15° multiplo de 3 es:', lista4)

# %%
"""
Haga un programa que lea las coordenadas (x1,y1,r1) y (x2,y2,r2) 
que corresponden al centro y al radio de dos círculos. Lea un punto de 
coordenadas (a,b). Determina si (a,b) está contenido: 
    a) dentro del círculo 1; 
    b) dentro del círculo 2; 
    c) dentro de ambos círculos; 
    d) fuera de ambos círculos. 
Recordemos que el círculo es el lugar geométrico de los puntos del plano cuya 
distancia a otro punto fijo, llamado centro, es menor o igual que una cantidad 
constante, llamada radio.
"""

def punto_pertenece_a_dos_cir(x1,y1,r1,x2,y2,r2,a,b):
    #formula de la circunferencia (a-x)**2+(b-y)**2=r**2
    #centro en(x,y)
    per_cir=(a-x1)**2+(b-y1)**2 ; per_cir_2=(a-x2)**2+(b-y2)**2
    rad1=r1**2                      ; rad2=r2**2
    
    return per_cir,rad1,rad2,per_cir_2
while True:
    try:
        X1=float(input("Ingrese la coordenada X del primer circulo = "))
        Y1=float(input("Ingrese la coordenada Y del primer circulo = "))
        R1=float(input("Ingrese el radio del primer circulo = "))
        X2=float(input("Ingrese la coordenada X del segundo circulo = "))
        Y2=float(input("Ingrese la coordenada Y del segundo circulo = "))
        R2=float(input("Ingrese el radio del segundo circulo = "))
        A=float(input("Ingrese la coordenada X a calcular = "))
        B=float(input("Ingrese la coordenada Y a calcular = "))
        break
    except ValueError:
        print("El caracter ingresado es incorrecto. Inténtelo de nuevo.")

per_cir,rad1,rad2,per_cir_2=punto_pertenece_a_dos_cir(X1,Y1,R1,X2,Y2,R2,A,B)
if per_cir<=rad1 and per_cir<=rad2:
    print("El punto pertenece a las dos circulos.")
elif per_cir<=rad1:
    print("El punto pertenece al circulo 1.")
elif per_cir_2<=rad2:
    print("El punto pertenece al circulo 2.")
else:
    print("El punto no pertenece a ningun circulo.")

# %%
"""
Sin utilizar el método .upper() para cadenas, escribir un programa que lea una 
cadena de texto y la imprima en mayúscula. 
Tenga en cuenta que el programa debe aceptar las letras con tilde, la ñ y la ü.
"""

m=['a','á','b','c','d','e','é','f','g','h','i','í','j','k','l','m','n','ñ',\
      'o','ó','p','q','r','s','t','u','ú','ü','v','w','x','y','z']
M=['A','Á','B','C','D','E','É','F','G','H','I','Í','J','K','L','M','N','Ñ',\
      'O','Ó','P','Q','R','S','T','U','Ú','Ü','V','W','X','Y','Z']

c=input('Digite una cadena de texto:')



for i in c:
    
    if i not in m:
        y=i
    
    else: 
        x=m.index(i)  #reemplaza cada elemento de la lista m

        y=M[x]       #por los elementos de la lista M

    print(y,end='')
else:
    print('.')

# %%
"""
Hacer un programa que lea dos palabras (podrían estar en mayúscula o minúscula)
y determine cual está primero en el diccionario. 
El programa debe soportar letras con tilde, la ü y la ñ.
"""

m=['a','á','b','c','d','e','é','f','g','h','i','í','j','k','l','m','n','ñ',
      'o','ó','p','q','r','s','t','u','ú','ü','v','w','x','y','z']
M=['A','Á','B','C','D','E','É','F','G','H','I','Í','J','K','L','M','N','Ñ',
      'O','Ó','P','Q','R','S','T','U','Ú','Ü','V','W','X','Y','Z']

x1=input('Digite la primera palabra:')
x2=input('Digite la segunda palabra:')

y=[]
z=[]


for i in x1:
    if i in m:
        c=m.index(i)    #retorna la posicion de la lista m
        y.append(c)     #agrega c a la lista y
    
    if i in M:
        a=M.index(i)
        y.append(a)

for i in x2:
    if i in m:
        r=m.index(i)
        z.append(r)
    
    if i in M:
        o=M.index(i)
        z.append(o)
        
if y < z :
    print('Esta primero en el diccionario:', x1)
else:
    print('Esta primero en el diciconario:', x2)

# %%
"""
Objetivos: Escriba un programa que lea una cadena de texto y la imprima \
como un triángulo. Por ejemplo, si la cadena entrada es: "Es una locura odiar \
a todas las rosas porque una te pinchó: renunciar a todos tus sueños porque \
uno de ellos no se realizó - El Principito", el programa debe imprimir:

         E
        sun
       alocu
      raodiar
     atodaslas
    rosasporque
   unatepinchó:r
  enunciaratodost
 ussueñosporqueuno
deellosnoserealizó-
   ElPrincipito
Observe que la última cadena queda centrada con respecto a la base del \
triángulo.
"""

#Bloque 1(librerias/modulos):
import math
#Bloque 2(Funciones):

'''Función que permite leer una cadena'''
def leer_cadena():
    while True:
        try:
            cadena= (input("ingerese la cadena: "))
            if type(cadena) != str:
                raise ValueError
            break
        except:
            print("La cadena ingresada no es valida")
    return(cadena)

    
#Bloque 3(Codigo):
#De la cadena inicial eliminar los espacios.
#Sacar la cantidad maxima de filas que contiene el arreglo, este obedece a una
#funcion cuadratica. el cuadrado del numero de filas determina la cantidad de 
#caracteres que se pueden acomodar.
#Imprimir, centrando el arreglo con la fila que contiene mas elementos

cad= leer_cadena()
cad = cad.replace(" ","")
long= len(cad)
filas= (len(cad)**(1/2))
if filas - filas//1 !=0:
    fila_mayor= math.ceil(filas -1)
else:
    fila_mayor= math.ceil(filas)
filas= math.ceil(filas)

for i in range (0,filas+1):
    print((cad[(i**2):((i+1)**2)]).center(fila_mayor*2))

# %%
"""
Leer una lista de números ya ordenados de forma ascendente y verificar 
que dicha lista está ordenada. Luego, leer un número e insertarlo en la 
lista en la posición que le corresponde a dicho número.
"""

a = int(input('ingrese el tamaño de la lista:'))
lista=[]
for x in range(a):
    numero=int(input(f"Ingrese un valor entero{x+1}:"))
    lista.append(numero)
   
for i in range(a-1):
    if lista[i]>lista[i+1]:
       print("La lista no está en orden")
       break  
    elif lista[i]<lista[i+1]:
       print(lista)
       print('La lista esta en orden')
num1=int(input('Ingrese un número'))
for i in range(a):
   if lista[i]>=num1:
        lista.insert(i,num1)
        break

if num1>max(lista):
     lista.insert(a+1,num1)      
     
print(lista)

# %%
"""
Leer una lista y determinar cuál es el segundo elemento más grande de dicha
lista. No utilice ningún tipo de algoritmo de ordenamiento
para realizar este ejercicio.
"""
a = int(input('ingrese el tamaño de la lista:'))
lis=[]
for x in range(a):
    numero=int(input(f"Ingrese un valor entero{x+1}:"))
    lis.append(numero)

print(lis)

b=lis.pop(lis.index(max(lis)))

d=max(lis)

print(f'el segundo valor mas grande es {d}')

# %%
"""
Leer una lista de números enteros y enumerar cuantos elementos se repiten exactamente dos veces. Utilizar para tal
fin el método count() de listas.
"""

lista=[]
contador=0
converge=0

while converge==0:
    lista.append(input('Ingrese elemento a añadir en la lista y escriba fin '
                       'cuando no quiera agregar mas:'))
    
    if 'fin' in lista:
        converge=1
        lista.remove('fin')
    
    
for i in (lista):
        
    if lista.count(i)==2:
        lista.remove(i)
        contador+=1
            
print('La cantidad de elementos que se repiten exactamente dos veces dentro '
      'de la lista es de:', contador)
